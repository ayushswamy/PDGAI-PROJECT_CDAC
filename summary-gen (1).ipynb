# %%
from datasets import load_dataset
#Load ILSUM-2.0 dataset english
ds = load_dataset("ILSUM/ILSUM-2.0", "English")
# Out:
# Downloading readme:   0%|          | 0.00/4.23k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/107M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/28342 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2895 [00:00<?, ? examples/s]

# %%
import pandas as pd

# Convert the dataset to Pandas DataFrames
df_train = ds['train'].to_pandas()
df_test = ds['test'].to_pandas()

# %%
df_train.head()
# Out:
#                      id                                            Heading  \
# 0  english_2023_train_0  Barbie Review: Greta Gerwig, Margot Robbie, Ry...
# 1  english_2023_train_1  Gadar 2: Sunny Deol-Ameesha Patel Starrer's Tr...
# 2  english_2023_train_2  Kartik Aaryan Ditches First Class To Fly In Ec...
# 3  english_2023_train_3  India's Anju, Now Fatima, Receives Land, Money...
# 4  english_2023_train_4  Himachal Pradesh Hotels Offer 50% Discount As ...
#
#                                              Summary  \
# 0  Barbie Movie Review: Ryan Gosling shines the b...
# 1  A source close to the film told News18 exclusi...
# 2  Kartik Aaryan was spotted flying in economy cl...
# 3  Abbasi had said that it was important to make ...
# 4  Flash floods and landslides caused by heavy do...
#
#                                              Article
# 0  Barbie Movie Review: One mention of Barbie and...
# 1  The highly anticipated Gadar 2, starring Sunny...
# 2  Kartik Aaryan, who is gearing up for the relea...
# 3  Indian woman, Anju who travelled to Pakistan t...
# 4  Himachal Pradesh, one of the worst hit states ...

# %%
import re
import pandas as pd
from sklearn.model_selection import train_test_split

# Function to clean text
def clean_text(text):
    #text = re.sub(r'<[^>]+>', '', text)  # remove HTML tags
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra spaces and strip
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)  # remove special characters
    return text

# %%
df = df_train[['Heading','Summary', 'Article']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28342 entries, 0 to 28341
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Heading  28342 non-null  object
#  1   Summary  28342 non-null  object
#  2   Article  28342 non-null  object
# dtypes: object(3)
# memory usage: 664.4+ KB

# %%
# Apply cleaning function to subtitles and summaries
#df_train['Article'] = df_train['Article'].apply(clean_text)
#df_train['Summary'] = df_train['Summary'].apply(clean_text)

# %%
# Filter rows where the Summary string length is more than 150 characters
filtered_df = df[df['Summary'].apply(len) > 150]

# %%
filtered_df
# Out:
#                                                  Heading  \
# 3      India's Anju, Now Fatima, Receives Land, Money...
# 4      Himachal Pradesh Hotels Offer 50% Discount As ...
# 7      Brij Bhushan Sharan Singh Claims 22 State Unit...
# 8      India's Tiger Population Estimate at 3,682 Aft...
# 9      MP: Administration Razes Houses of Two Men Acc...
# ...                                                  ...
# 28337  Japan approves plan to release millions of ton...
# 28338  16 killed, hundreds stranded on Indonesian mou...
# 28339  Gadhafi’s son Seif al-Islam released after mor...
# 28340  Rescued Thai boys to be ordained in Buddhist c...
# 28341  Karachi to award citizens who identify people ...
#
#                                                  Summary  \
# 3      Abbasi had said that it was important to make ...
# 4      Flash floods and landslides caused by heavy do...
# 7      Brij Bhushan Sharan Singh will have 'his candi...
# 8      The latest estimate is said to cover areas of ...
# 9      The accused, Ravindra Kumar and Atul Bhadoliya...
# ...                                                  ...
# 28337  A massive earthquake and tsunami in 2011 destr...
# 28338  Over 680 tourists from France, Thailand, the N...
# 28339  Seif al-Islam, the son and one-time heir appar...
# 28340  Most members of the Thai youth football team r...
# 28341  The government of Pakistan's Sindh province ha...
#
#                                                  Article
# 3      Indian woman, Anju who travelled to Pakistan t...
# 4      Himachal Pradesh, one of the worst hit states ...
# 7      Outgoing Wrestling Federation of India (WFI) p...
# 8      India's tiger population is estimated to be 3,...
# 9      The local administration on Saturday demolishe...
# ...                                                  ...
# 28337  FILE - Tanks storing treated radioactive water...
# 28338  Villagers clear debris caused by an earthquake...
# 28339  Seif al-Islam, the son and one-time heir appar...
# 28340  Thai BoysMost members of the Thai youth footba...
# 28341  Karachi to award citizens who identify people ...
#
# [21830 rows x 3 columns]

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21830 entries, 3 to 28341
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Heading  21830 non-null  object
#  1   Summary  21830 non-null  object
#  2   Article  21830 non-null  object
# dtypes: object(3)
# memory usage: 682.2+ KB

# %%
# Splitting labeled data for training
train_data, val_data = train_test_split(filtered_df, test_size=0.2, random_state=42)

# %%
# Reset the index of your DataFrames
train_data = train_data.reset_index(drop=True)
val_data = val_data.reset_index(drop=True)

# %%
train_data

# %%
from transformers import BartForConditionalGeneration, Trainer, TrainingArguments
from transformers import BartTokenizer
from torch.utils.data import Dataset, DataLoader

# %%
tokenizer = BartTokenizer.from_pretrained('facebook/bart-large')

# %%
class CustomSummarizationDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length=512):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.max_length = max_length
        self.inputs = self.data['Article']
        self.targets = self.data['Summary']

    def __len__(self):
        return len(self.inputs)

    def __getitem__(self, index):
        input_text = str(self.inputs[index])
        target_text = str(self.targets[index])

        # Tokenizing the input and target texts
        input_tokens = self.tokenizer.encode_plus(input_text, max_length=self.max_length, padding='max_length', truncation=True, return_tensors="pt")
        target_tokens = self.tokenizer.encode_plus(target_text, max_length=self.max_length, padding='max_length', truncation=True, return_tensors="pt")

        return {
            'input_ids': input_tokens['input_ids'].flatten(),
            'attention_mask': input_tokens['attention_mask'].flatten(),
            'labels': target_tokens['input_ids'].flatten()
        }

# %%
# Assuming your DataFrame is named df and already split into train_data and val_data
train_dataset = CustomSummarizationDataset(train_data, tokenizer)
val_dataset = CustomSummarizationDataset(val_data, tokenizer)

# Creating data loaders
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=8)

# %%
model = BartForConditionalGeneration.from_pretrained('facebook/bart-large')

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    evaluation_strategy='epoch',
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    # data_collator defaults to DataCollatorWithPadding, adjust if necessary
)

trainer.train()

# %%
# Save the fine-tuned model
trainer.save_model("./fine_tuned_bart_model")
